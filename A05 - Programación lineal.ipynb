# %% [markdown]
# Alvaro Ramirez Zenteno 05/09/2024

# %% [markdown]
# A05 - Programación lineal

# %% [markdown]
# ![image.png](attachment:8ab31edd-aebd-4650-a826-e6165a3688c9.png)

# %% [markdown]
# 1.
# Minimizar costo total
#
#
# 2. Variables de control
# gramos de pollo=x_1
# gramos de carne=x_2
# gramos de cordero= x_3
# gramos de arroz=_x_4
# gramos de trigo=x_5
# gramos de gal=x_6
#
# 3. Funcion costo
# Costo_total= $0.0.12*(x_1)+0.009*(x_2)+0.010*(x_3)+0.003*(x_4)+0.005*(x_5)+0.002*(x_6)$
#
# 4. Info adicional
#     * Pollo
#         * Proteina 10%
#         * Grasa 8%
#         * Fibra 0.1%
#         * Sal0 0.2%
#
#     * Carne
#         * Proteina 20%
#         * Grasa 10%
#         * Fibra 0.5%
#         * Sal 0.5%
#
#     * Cordero
#         * Proteina 15%
#         * Grasa 11%
#         * Fibra 0.5%
#         * Sal0 0.7%
#     * Arroz
#         * Proteina 0%
#         * Grasa 1%
#         * Fibra 10%
#         * Sal0 0.2%
#     * Trigo
#         * Proteina 4%
#         * Grasa 1%
#         * Fibra 15%
#         * Sal0 0.8%
#     * Gel
#         * Proteina 0%
#         * Grasa 0%
#         * Fibra 0%
#         * Sal0 0%
#
# $0.10*x_1+0.20x_2+0.15*x_3+0*x_4+0.4*x_5+0*x_6 \geq 0.9$
