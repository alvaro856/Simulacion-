# %% [markdown]
# Simulación Matematica

# %% [markdown]
# Alvaro Ramirez Zenteno 28/08/2024

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x):
    return x**2 - 4*x + 2
x = np.linspace(-2, 6, 400)
y = f(x)


plt.plot(x, y)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x): 
    return np.sin(3*x)
x = np.linspace(-2, 6, 400)
y = f(x)


plt.plot(x, y)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x): 
    return np.exp(2*x) - 3
x = np.linspace(-2, 6, 400)
y = f(x)


plt.plot(x, y)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x): 
    return np.sqrt(x**2 - 4)
x = np.linspace(2, 3, 100)
y = f(x)


plt.plot(x, y)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x): 
    return np.cos(x + np.pi/4)
x = np.linspace(-2, 12, 300)
y = f(x)


plt.plot(x, y)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
def y1(x):
    return 2*x + 1

def y2(x):
    return -x + 4

def y3(x):
    return x**2
    
x = np.linspace(-2, 12, 300)
y = y1valor = y1(x)
y2valor = y2(x)
y3valor = y3(x)


plt.plot(x, y1valor)
plt.plot(x, y2valor)
plt.plot(x, y3valor)
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
def y1(x):
    return np.sin(x)

def y2(x):
    return np.cos(x)
    
x = np.linspace(-1, 6, 100)
y = y1sen = y1(x)
y2cos = y2(x)


plt.plot(x, y1sen)
plt.plot(x, y2cos)
plt.grid()

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 400)      x = np.linspace(-2, 12, 300)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir las funciones
def sin_x(x):
    return np.sin(x)

def cos_x(x):
    return np.cos(x)

# Generar un conjunto de valores de x
x = np.linspace(-2*np.pi, 2*np.pi, 400)

# Calcular los valores de sin(x) y cos(x) para cada x
y_sin = sin_x(x)
y_cos = cos_x(x)

# Crear la gráfica
plt.figure(figsize=(8, 6))

# Graficar cada función
plt.plot(x, y_sin, label=r'$\sin(x)$')
plt.plot(x, y_cos, label=r'$\cos(x)$')

# Agregar títulos y etiquetas
plt.title('Gráficas de $\sin(x)$ y $\cos(x)$')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)

# Mostrar la leyenda
plt.legend()

# Mostrar la gráfica
plt.show()
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\alvar\AppData\Local\Temp\ipykernel_29688\577282644.py:26: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Gráficas de $\sin(x)$ y $\cos(x)$')
